# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# %matplotlib widget

# %%
ce_shp = gpd.read_file("../shapefiles/CE_Municipios_2020.shp")

# %%
ce_crs = ce_shp.crs
#ce_crs

# %%
ce_shp.to_crs(epsg=3395, inplace=True)

# %%
ce_shp.plot();
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ce_shp[ce_shp['NM_MUN'] == 'Redenção'].plot();
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
redencao_centroid = ce_shp[ce_shp['NM_MUN'] == 'Redenção'].centroid

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
ce_shp[ce_shp['NM_MUN'] == 'Redenção'].plot(ax=ax, color='white', edgecolor='black')
redencao_centroid.plot(ax=ax, marker='o', color='red', markersize=5);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
redencao_buffer = redencao_centroid.buffer(60_000)

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
ce_shp.plot(ax=ax, color='white', edgecolor='black')
redencao_centroid.plot(ax=ax, marker='o', color='red', markersize=5)
redencao_buffer.plot(ax=ax, edgecolors=("red",), alpha=.4);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
redencao_buffer_gdf = gpd.GeoDataFrame({'geometry': redencao_buffer})
ce_intersection = gpd.overlay(ce_shp, redencao_buffer_gdf, how='intersection')

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
ce_intersection.plot(ax=ax);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ce_intersection
# Out:
#      CD_MUN        NM_MUN SIGLA_UF  AREA_KM2  \
# 0   2300150       Acarape       CE   130.002
# 1   2300903      Apuiarés       CE   543.980
# 2   2301000       Aquiraz       CE   480.236
# 3   2301208     Aracoiaba       CE   643.988
# 4   2301406       Aratuba       CE   119.758
# 5   2301950      Barreira       CE   260.003
# 6   2302107      Baturité       CE   314.075
# 7   2302206      Beberibe       CE  1596.751
# 8   2302800       Canindé       CE  3032.390
# 9   2302909    Capistrano       CE   226.549
# 10  2303006      Caridade       CE   926.271
# 11  2303501      Cascavel       CE   838.115
# 12  2303709       Caucaia       CE  1223.246
# 13  2303931         Choró       CE   815.268
# 14  2303956    Chorozinho       CE   296.431
# 15  2304285       Eusébio       CE    78.818
# 16  2304400     Fortaleza       CE   312.353
# 17  2304954       Guaiúba       CE   256.053
# 18  2305100  Guaramiranga       CE    90.817
# 19  2305233     Horizonte       CE   160.557
# 20  2305266     Ibaretama       CE   879.255
# 21  2306256     Itaitinga       CE   153.686
# 22  2306504      Itapiúna       CE   593.231
# 23  2307650     Maracanaú       CE   105.071
# 24  2307700    Maranguape       CE   583.505
# 25  2308708   Morada Nova       CE  2763.971
# 26  2309102       Mulungu       CE    97.951
# 27  2309458         Ocara       CE   763.075
# 28  2309607       Pacajus       CE   250.304
# 29  2309706      Pacatuba       CE   133.236
# 30  2309805        Pacoti       CE   112.433
# 31  2310100      Palmácia       CE   128.896
# 32  2310407      Paramoti       CE   539.238
# 33  2310704    Pentecoste       CE  1379.836
# 34  2310852   Pindoretama       CE    74.033
# 35  2311306       Quixadá       CE  2020.586
# 36  2311603      Redenção       CE   247.989
#
#                                              geometry
# 0   POLYGON ((-4302837.214 -460172.544, -4302789.4...
# 1   POLYGON ((-4365020.878 -436767.088, -4363066.5...
# 2   POLYGON ((-4260154.923 -445699.862, -4260167.6...
# 3   POLYGON ((-4315270.630 -476590.059, -4315212.4...
# 4   POLYGON ((-4345495.378 -482594.572, -4345376.3...
# 5   POLYGON ((-4293645.527 -468768.475, -4293284.3...
# 6   POLYGON ((-4324578.103 -468213.553, -4324528.1...
# 7   MULTIPOLYGON (((-4264170.489 -501643.597, -426...
# 8   POLYGON ((-4374901.194 -467752.363, -4374150.4...
# 9   POLYGON ((-4335332.578 -481493.408, -4335322.6...
# 10  POLYGON ((-4339409.140 -447877.452, -4336628.5...
# 11  POLYGON ((-4255230.901 -465316.867, -4255398.2...
# 12  POLYGON ((-4297588.404 -412474.131, -4297587.1...
# 13  POLYGON ((-4354646.853 -512321.221, -4354660.7...
# 14  POLYGON ((-4272442.444 -466966.423, -4272919.7...
# 15  POLYGON ((-4276717.102 -423714.064, -4276719.2...
# 16  POLYGON ((-4279412.044 -421678.215, -4279368.2...
# 17  POLYGON ((-4302436.852 -443332.282, -4300914.3...
# 18  POLYGON ((-4335416.321 -462769.631, -4335361.0...
# 19  POLYGON ((-4285915.171 -449441.055, -4285878.5...
# 20  POLYGON ((-4308820.686 -510404.614, -4308684.9...
# 21  POLYGON ((-4288218.739 -430209.726, -4288049.0...
# 22  POLYGON ((-4344615.603 -496900.945, -4344576.9...
# 23  POLYGON ((-4301151.680 -420649.391, -4301131.9...
# 24  POLYGON ((-4306216.596 -426808.449, -4306147.9...
# 25  POLYGON ((-4266551.562 -500123.811, -4266533.5...
# 26  POLYGON ((-4339831.478 -472129.544, -4336696.7...
# 27  POLYGON ((-4289245.430 -483842.689, -4289237.5...
# 28  POLYGON ((-4290386.227 -457123.335, -4290289.0...
# 29  POLYGON ((-4290535.664 -427174.930, -4290744.8...
# 30  POLYGON ((-4335002.709 -458090.606, -4334992.9...
# 31  POLYGON ((-4314778.677 -450726.698, -4314774.7...
# 32  POLYGON ((-4364054.386 -448003.173, -4364098.8...
# 33  POLYGON ((-4336604.084 -413969.774, -4336594.2...
# 34  POLYGON ((-4264760.335 -444043.882, -4264723.1...
# 35  POLYGON ((-4336244.980 -516308.369, -4336181.3...
# 36  POLYGON ((-4318546.038 -458558.037, -4318487.4...

# %%
ba_shp = gpd.read_file("../shapefiles/BA_Municipios_2020.shp")

# %%
ba_shp.to_crs(epsg=3395, inplace=True)

# %%
ba_shp.plot();
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ba_shp[ba_shp['NM_MUN'] == 'São Francisco do Conde'].plot();
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sfc_centroid = ba_shp[ba_shp['NM_MUN'] == 'São Francisco do Conde'].centroid

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
ba_shp[ba_shp['NM_MUN'] == 'São Francisco do Conde'].plot(ax=ax, color='white', edgecolor='black')
sfc_centroid.plot(ax=ax, marker='o', color='red', markersize=5);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sfc_buffer = sfc_centroid.buffer(60_000)

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
ba_shp.plot(ax=ax, color='white', edgecolor='black')
sfc_centroid.plot(ax=ax, marker='o', color='red', markersize=5)
sfc_buffer.plot(ax=ax, edgecolors=("red",), alpha=.4);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sfc_buffer_gdf = gpd.GeoDataFrame({'geometry': sfc_buffer})
ba_intersection = gpd.overlay(ba_shp, sfc_buffer_gdf, how='intersection')

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
ba_intersection.plot(ax=ax);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ba_intersection
# Out:
#      CD_MUN                   NM_MUN SIGLA_UF  AREA_KM2  \
# 0   2900702               Alagoinhas       BA   707.835
# 1   2901106         Amélia Rodrigues       BA   166.872
# 2   2901700          Antônio Cardoso       BA   293.530
# 3   2902054                   Araçás       BA   474.577
# 4   2902203                  Aramari       BA   368.947
# 5   2902302                 Aratuípe       BA   174.012
# 6   2904852  Cabaceiras do Paraguaçu       BA   222.026
# 7   2904902                Cachoeira       BA   394.894
# 8   2905701                 Camaçari       BA   785.421
# 9   2906501                 Candeias       BA   251.808
# 10  2907509                     Catu       BA   426.955
# 11  2908200       Conceição da Feira       BA   164.798
# 12  2908309     Conceição do Almeida       BA   284.836
# 13  2908507     Conceição do Jacuípe       BA   114.869
# 14  2908903         Coração de Maria       BA   378.420
# 15  2909802           Cruz das Almas       BA   139.117
# 16  2910057             Dias d'Ávila       BA   183.759
# 17  2910800         Feira de Santana       BA  1304.425
# 18  2911600    Governador Mangabeira       BA   106.848
# 19  2914505                    Irará       BA   267.880
# 20  2916104                Itaparica       BA   121.373
# 21  2917805                Jaguaripe       BA   863.424
# 22  2919207         Lauro de Freitas       BA    58.043
# 23  2919926            Madre de Deus       BA    32.201
# 24  2920601               Maragogipe       BA   437.610
# 25  2921005         Mata de São João       BA   605.168
# 26  2922201           Muniz Ferreira       BA   104.540
# 27  2922300                 Muritiba       BA    86.311
# 28  2922508                   Nazaré       BA   278.629
# 29  2924108                   Pedrão       BA   158.488
# 30  2925204                   Pojuca       BA   314.932
# 31  2927309     Salinas da Margarida       BA   150.569
# 32  2927408                 Salvador       BA   693.453
# 33  2928604              Santo Amaro       BA   494.502
# 34  2928802            Santo Estêvão       BA   360.334
# 35  2929008                São Félix       BA   103.226
# 36  2929107               São Felipe       BA   222.407
# 37  2929206   São Francisco do Conde       BA   269.715
# 38  2929305   São Gonçalo dos Campos       BA   294.768
# 39  2929503   São Sebastião do Passé       BA   536.678
# 40  2929602                  Sapeaçu       BA   131.218
# 41  2929750                  Saubara       BA   166.428
# 42  2930709             Simões Filho       BA   201.418
# 43  2931400          Teodoro Sampaio       BA   244.613
# 44  2931707               Terra Nova       BA   193.241
# 45  2933208                Vera Cruz       BA   297.537
#
#                                              geometry
# 0   POLYGON ((-4266052.268 -1361449.573, -4266100....
# 1   POLYGON ((-4305308.127 -1384619.403, -4305284....
# 2   POLYGON ((-4350375.885 -1377178.968, -4350372....
# 3   POLYGON ((-4258214.236 -1367956.624, -4260516....
# 4   POLYGON ((-4284806.537 -1352667.939, -4284745....
# 5   POLYGON ((-4340196.686 -1455410.983, -4340190....
# 6   POLYGON ((-4349566.848 -1394110.193, -4349559....
# 7   POLYGON ((-4328851.737 -1395787.451, -4328820....
# 8   POLYGON ((-4251092.248 -1388657.921, -4251083....
# 9   POLYGON ((-4283903.469 -1403861.170, -4283912....
# 10  POLYGON ((-4269720.299 -1362876.125, -4269719....
# 11  POLYGON ((-4344620.942 -1386606.129, -4344542....
# 12  POLYGON ((-4356999.666 -1422748.035, -4357015....
# 13  POLYGON ((-4312944.773 -1368692.275, -4312923....
# 14  POLYGON ((-4314495.371 -1352246.866, -4314491....
# 15  POLYGON ((-4360382.668 -1408303.724, -4360279....
# 16  POLYGON ((-4269536.699 -1397564.180, -4269506....
# 17  POLYGON ((-4327057.192 -1356790.377, -4327032....
# 18  POLYGON ((-4343958.189 -1399727.535, -4343938....
# 19  POLYGON ((-4307942.302 -1351040.017, -4308241....
# 20  POLYGON ((-4292942.401 -1441413.520, -4292690....
# 21  POLYGON ((-4320194.524 -1441169.798, -4320135....
# 22  POLYGON ((-4268563.328 -1428521.013, -4268548....
# 23  POLYGON ((-4299793.558 -1419128.494, -4299625....
# 24  POLYGON ((-4337361.349 -1415570.062, -4337339....
# 25  POLYGON ((-4242833.717 -1394064.578, -4242834....
# 26  POLYGON ((-4347468.641 -1444349.192, -4347239....
# 27  POLYGON ((-4360106.851 -1403992.102, -4359897....
# 28  POLYGON ((-4345940.212 -1431030.501, -4345860....
# 29  POLYGON ((-4293643.367 -1350950.608, -4293643....
# 30  POLYGON ((-4248067.343 -1381414.990, -4248105....
# 31  POLYGON ((-4308634.867 -1435542.498, -4308523....
# 32  POLYGON ((-4292847.442 -1420245.752, -4292609....
# 33  POLYGON ((-4323117.142 -1378480.901, -4323092....
# 34  POLYGON ((-4357327.308 -1391478.569, -4357213....
# 35  POLYGON ((-4336374.219 -1408464.123, -4336346....
# 36  POLYGON ((-4347274.740 -1419638.847, -4347255....
# 37  POLYGON ((-4303792.387 -1399094.224, -4303772....
# 38  POLYGON ((-4334174.969 -1375193.041, -4333441....
# 39  POLYGON ((-4290252.216 -1383769.193, -4290245....
# 40  POLYGON ((-4360258.909 -1415251.935, -4359836....
# 41  POLYGON ((-4314950.188 -1418316.660, -4314932....
# 42  POLYGON ((-4274832.337 -1411474.156, -4274623....
# 43  POLYGON ((-4298476.224 -1356216.947, -4298488....
# 44  POLYGON ((-4293431.611 -1372377.241, -4293419....
# 45  POLYGON ((-4307324.742 -1441957.139, -4307297....
